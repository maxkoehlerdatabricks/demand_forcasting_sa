# %%
catalogName = "maxkoehler_demos"
dbName = "demand_db"

# %%
# Delete the schema
spark.sql(f"DROP SCHEMA IF EXISTS {catalogName}.{dbName} CASCADE")

# %%
# Create the catalog
spark.sql(f"""create catalog if not exists {catalogName}""")

# %%
###### Delete the catalog, careful (!)
##spark.sql(f"DROP CATALOG IF EXISTS {catalogName} CASCADE")
